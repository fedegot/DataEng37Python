# %%
import pandas as pd

# %%
iris = pd.read_csv("iris.csv", sep=',', header='infer')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head() #GRAB THE FIRST OF THE CSV file
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df1 = iris[['sepal_length', 'sepal_width']]
df1
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
iris.sort_values(by=['petal_length'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species rank
# 22            4.6          3.6           1.0          0.2     setosa  NaT
# 13            4.3          3.0           1.1          0.1     setosa  NaT
# 14            5.8          4.0           1.2          0.2     setosa  NaT
# 35            5.0          3.2           1.2          0.2     setosa  NaT
# 36            5.5          3.5           1.3          0.2     setosa  NaT
# ..            ...          ...           ...          ...        ...  ...
# 131           7.9          3.8           6.4          2.0  virginica  NaT
# 105           7.6          3.0           6.6          2.1  virginica  NaT
# 117           7.7          3.8           6.7          2.2  virginica  NaT
# 122           7.7          2.8           6.7          2.0  virginica  NaT
# 118           7.7          2.6           6.9          2.3  virginica  NaT
#
# [150 rows x 6 columns]

# %%
psp = iris.mean()
psp
# Out:
# C:\Users\got_a\AppData\Local\Temp\ipykernel_3688\2503437952.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   psp = iris.mean()
# C:\Users\got_a\AppData\Local\Temp\ipykernel_3688\2503437952.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   psp = iris.mean()
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
spec = iris.groupby('species')
spec

# %%
spec.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species rank
# 0             5.1          3.5           1.4          0.2      setosa  NaT
# 1             4.9          3.0           1.4          0.2      setosa  NaT
# 2             4.7          3.2           1.3          0.2      setosa  NaT
# 3             4.6          3.1           1.5          0.2      setosa  NaT
# 4             5.0          3.6           1.4          0.2      setosa  NaT
# 50            7.0          3.2           4.7          1.4  versicolor  NaT
# 51            6.4          3.2           4.5          1.5  versicolor  NaT
# 52            6.9          3.1           4.9          1.5  versicolor  NaT
# 53            5.5          2.3           4.0          1.3  versicolor  NaT
# 54            6.5          2.8           4.6          1.5  versicolor  NaT
# 100           6.3          3.3           6.0          2.5   virginica  NaT
# ...

# %%
spec.describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
spec.mean() # find the mean by species
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
iris.groupby("species").mean() # find the mean by species
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
iris[iris["species"] == "setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species rank
# 0            5.1          3.5           1.4          0.2  setosa  NaT
# 1            4.9          3.0           1.4          0.2  setosa  NaT
# 2            4.7          3.2           1.3          0.2  setosa  NaT
# 3            4.6          3.1           1.5          0.2  setosa  NaT
# 4            5.0          3.6           1.4          0.2  setosa  NaT
# 5            5.4          3.9           1.7          0.4  setosa  NaT
# 6            4.6          3.4           1.4          0.3  setosa  NaT
# 7            5.0          3.4           1.5          0.2  setosa  NaT
# 8            4.4          2.9           1.4          0.2  setosa  NaT
# 9            4.9          3.1           1.5          0.1  setosa  NaT
# 10           5.4          3.7           1.5          0.2  setosa  NaT
# 11           4.8          3.4           1.6          0.2  setosa  NaT
# ...

# %%
sepal = iris[['sepal_length', 'sepal_width', species]]
petal = iris[['petal_length', 'petal_width', species]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 sepal = iris[['sepal_length', 'sepal_width', species]]
#       2 petal = iris[['petal_length', 'petal_width', species]]
#
# NameError: name 'species' is not defined

# %%
#MERGIN

# %%
pd.merge(sepal, petal, home="inner", right_index=True, left_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 pd.merge(sepal, petal, home="inner", right_index=True, left_index=True)
#
# NameError: name 'sepal' is not defined

# %%
flights = sns.load_dataset("flights")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [88], in <cell line: 1>()
# ----> 1 flights = sns.load_dataset("flights")
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_pivot = flights.pivot('year', 'month', 'passengers')
flights_pivot #order the data with years as index month as head passenger as data
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights_pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
flights_stack = flights_pivot.stack()
flights_stack # stack the data by year
# Out:
# year  month
# 1949  Jan      112
#       Feb      118
#       Mar      132
#       Apr      129
#       May      121
#               ...
# 1960  Aug      606
#       Sep      508
#       Oct      461
#       Nov      390
#       Dec      432
# Length: 144, dtype: int64

# %%
flights_stack[1955, 'Apr']
# Out:
# 269

# %%
sns.get_dataset_names() # all the dataset fo sns
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']
